# %%
import os
import numpy as np
import pandas as pd
from ete3 import Tree
import random
import subprocess
random.seed(191919)  # Set Random Seed for Reproducibility

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/results_braycurtis/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_bray_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
htPath
# Out:
# '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/newick_warblers.newick'

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
#   |   /-BAWW
# --|  |
#   |  |      /-NAWA
#   |  |   /-|
#   |  |  |   \-COYE
#    \-|  |
#      |  |         /-HOWA
#      |  |      /-|
#      |  |     |   \-AMRE
#      |  |     |
#       \-|   /-|   /-BTBW
#         |  |  |  |
#         |  |  |  |         /-NOPA
#         |  |  |  |      /-|
#         |  |   \-|     |   \-MAWA
#         |  |     |   /-|
#         |  |     |  |  |   /-BLBW
#          \-|     |  |   \-|
#            |      \-|      \-CSWA
#            |        |
#            |        |   /-MYWA
#            |         \-|
#            |            \-BTNW
#            |
#             \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-COYE
#   |
# --|   /-CSWA
#   |  |
#    \-|      /-OVEN
#      |   /-|
#      |  |   \-BAWW
#       \-|
#         |   /-BTNW
#         |  |
#          \-|      /-AMRE
#            |   /-|
#            |  |   \-HOWA
#             \-|
#               |   /-NAWA
#               |  |
#                \-|   /-CAWA
#                  |  |
#                   \-|   /-BTBW
#                     |  |
#                      \-|      /-NOPA
#                        |   /-|
#                        |  |   \-BLBW
#                         \-|
#                           |   /-MYWA
#                            \-|
#                               \-MAWA
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  12.0
# Normalized Score: 0.9166666666666666
# Random Trees with Equivalent or More Congruent Score: 2357
# Total Trees: 10000
# P-Value: 0.2357
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   33.0
# Max Stochastic Metric:  74.0
# Normalized Score: 0.44594594594594594
# Random Trees with Equivalent or More Congruent Score: 1
# Total Trees: 10000
# P-Value: 0.0001
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   9.0
# Max Stochastic Metric:  11.0
# Normalized Score: 0.8181818181818182
# Random Trees with Equivalent or More Congruent Score: 408
# Total Trees: 10000
# P-Value: 0.0408
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   25.0
# Max Stochastic Metric:  49.0
# Normalized Score: 0.5102040816326531
# Random Trees with Equivalent or More Congruent Score: 101
# Total Trees: 10000
# P-Value: 0.0101

# %%
######----------UNIFRAC-----------########
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/results_unifrac/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_unifrac_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
#   |   /-BAWW
# --|  |
#   |  |      /-NAWA
#   |  |   /-|
#   |  |  |   \-COYE
#    \-|  |
#      |  |         /-HOWA
#      |  |      /-|
#      |  |     |   \-AMRE
#      |  |     |
#       \-|   /-|   /-BTBW
#         |  |  |  |
#         |  |  |  |         /-NOPA
#         |  |  |  |      /-|
#         |  |   \-|     |   \-MAWA
#         |  |     |   /-|
#         |  |     |  |  |   /-BLBW
#          \-|     |  |   \-|
#            |      \-|      \-CSWA
#            |        |
#            |        |   /-MYWA
#            |         \-|
#            |            \-BTNW
#            |
#             \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-HOWA
#   |
# --|   /-BLBW
#   |  |
#   |  |      /-CSWA
#    \-|   /-|
#      |  |   \-BAWW
#      |  |
#       \-|      /-BTNW
#         |   /-|
#         |  |  |   /-NOPA
#         |  |   \-|
#          \-|      \-BTBW
#            |
#            |   /-AMRE
#            |  |
#             \-|   /-NAWA
#               |  |
#               |  |      /-MAWA
#                \-|   /-|
#                  |  |  |   /-MYWA
#                  |  |   \-|
#                   \-|      \-CAWA
#                     |
#                     |   /-COYE
#                      \-|
#                         \-OVEN
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   12.0
# Max Stochastic Metric:  12.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   52.0
# Max Stochastic Metric:  73.0
# Normalized Score: 0.7123287671232876
# Random Trees with Equivalent or More Congruent Score: 4925
# Total Trees: 10000
# P-Value: 0.4925
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  11.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   34.0
# Max Stochastic Metric:  49.0
# Normalized Score: 0.6938775510204082
# Random Trees with Equivalent or More Congruent Score: 3688
# Total Trees: 10000
# P-Value: 0.3688

# %%
######----------WEIGHTED UNIFRAC-----------########
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/results_weighted_unifrac/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_weightedunifrac_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
#   |   /-BAWW
# --|  |
#   |  |      /-NAWA
#   |  |   /-|
#   |  |  |   \-COYE
#    \-|  |
#      |  |         /-HOWA
#      |  |      /-|
#      |  |     |   \-AMRE
#      |  |     |
#       \-|   /-|   /-BTBW
#         |  |  |  |
#         |  |  |  |         /-NOPA
#         |  |  |  |      /-|
#         |  |   \-|     |   \-MAWA
#         |  |     |   /-|
#         |  |     |  |  |   /-BLBW
#          \-|     |  |   \-|
#            |      \-|      \-CSWA
#            |        |
#            |        |   /-MYWA
#            |         \-|
#            |            \-BTNW
#            |
#             \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-COYE
#   |
# --|   /-CSWA
#   |  |
#   |  |   /-OVEN
#    \-|  |
#      |  |      /-NAWA
#      |  |     |
#      |  |     |      /-MAWA
#       \-|   /-|   /-|
#         |  |  |  |  |   /-NOPA
#         |  |  |  |   \-|
#         |  |   \-|      \-MYWA
#         |  |     |
#          \-|     |   /-BTNW
#            |      \-|
#            |         \-CAWA
#            |
#            |   /-BLBW
#            |  |
#             \-|      /-BTBW
#               |   /-|
#               |  |   \-BAWW
#                \-|
#                  |   /-AMRE
#                   \-|
#                      \-HOWA
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  12.0
# Normalized Score: 0.9166666666666666
# Random Trees with Equivalent or More Congruent Score: 2293
# Total Trees: 10000
# P-Value: 0.2293
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   40.0
# Max Stochastic Metric:  70.0
# Normalized Score: 0.5714285714285714
# Random Trees with Equivalent or More Congruent Score: 64
# Total Trees: 10000
# P-Value: 0.0064
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  11.0
# Normalized Score: 0.9090909090909091
# Random Trees with Equivalent or More Congruent Score: 2691
# Total Trees: 10000
# P-Value: 0.2691
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   34.0
# Max Stochastic Metric:  51.0
# Normalized Score: 0.6666666666666666
# Random Trees with Equivalent or More Congruent Score: 3705
# Total Trees: 10000
# P-Value: 0.3705

# %%
######----------JACCARD for revision 2022-----------########
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/results_jaccard/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_jaccard_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar ./TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
#   |   /-BAWW
# --|  |
#   |  |      /-NAWA
#   |  |   /-|
#   |  |  |   \-COYE
#    \-|  |
#      |  |         /-HOWA
#      |  |      /-|
#      |  |     |   \-AMRE
#      |  |     |
#       \-|   /-|   /-BTBW
#         |  |  |  |
#         |  |  |  |         /-NOPA
#         |  |  |  |      /-|
#         |  |   \-|     |   \-MAWA
#         |  |     |   /-|
#         |  |     |  |  |   /-BLBW
#          \-|     |  |   \-|
#            |      \-|      \-CSWA
#            |        |
#            |        |   /-MYWA
#            |         \-|
#            |            \-BTNW
#            |
#             \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-BAWW
#   |
#   |         /-COYE
#   |      /-|
#   |     |   \-OVEN
#   |   /-|
#   |  |  |   /-BTNW
# --|  |  |  |
#   |  |   \-|   /-CSWA
#   |  |     |  |
#   |  |      \-|   /-BTBW
#   |  |        |  |
#   |  |         \-|   /-NAWA
#   |  |           |  |
#   |  |           |  |      /-NOPA
#    \-|            \-|   /-|
#      |              |  |  |   /-MYWA
#      |              |  |   \-|
#      |               \-|      \-CAWA
#      |                 |
#      |                 |   /-BLBW
#      |                  \-|
#      |                     \-MAWA
#      |
#      |   /-AMRE
#       \-|
#          \-HOWA
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  12.0
# Normalized Score: 0.9166666666666666
# Random Trees with Equivalent or More Congruent Score: 2351
# Total Trees: 10000
# P-Value: 0.2351
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   33.0
# Max Stochastic Metric:  73.0
# Normalized Score: 0.4520547945205479
# Random Trees with Equivalent or More Congruent Score: 4
# Total Trees: 10000
# P-Value: 0.0004
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  11.0
# Normalized Score: 0.9090909090909091
# Random Trees with Equivalent or More Congruent Score: 2733
# Total Trees: 10000
# P-Value: 0.2733
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   31.0
# Max Stochastic Metric:  49.0
# Normalized Score: 0.6326530612244898
# Random Trees with Equivalent or More Congruent Score: 1570
# Total Trees: 10000
# P-Value: 0.157
