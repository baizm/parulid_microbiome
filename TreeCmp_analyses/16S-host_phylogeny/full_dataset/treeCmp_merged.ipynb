# %%
import os
import numpy as np
import pandas as pd
from ete3 import Tree
import random
import subprocess
random.seed(191919)  # Set Random Seed for Reproducibility

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/results_braycurtis/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_bray_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
# --|   /-WEWA
#   |  |
#   |  |   /-BAWW
#    \-|  |
#      |  |      /-NAWA
#      |  |   /-|
#      |  |  |   \-COYE
#       \-|  |
#         |  |         /-HOWA
#         |  |      /-|
#         |  |     |   \-AMRE
#         |  |     |
#          \-|   /-|   /-BTBW
#            |  |  |  |
#            |  |  |  |         /-NOPA
#            |  |  |  |      /-|
#            |  |   \-|     |   \-MAWA
#            |  |     |   /-|
#            |  |     |  |  |   /-BLBW
#             \-|     |  |   \-|
#               |      \-|      \-CSWA
#               |        |
#               |        |   /-MYWA
#               |         \-|
#               |            \-BTNW
#               |
#                \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-NAWA
#   |
# --|   /-WEWA
#   |  |
#    \-|   /-COYE
#      |  |
#      |  |      /-CSWA
#       \-|   /-|
#         |  |   \-BTNW
#         |  |
#         |  |      /-AMRE
#          \-|   /-|
#            |  |   \-HOWA
#            |  |
#            |  |      /-MYWA
#             \-|   /-|
#               |  |  |   /-BLBW
#               |  |   \-|
#               |  |     |   /-NOPA
#                \-|      \-|
#                  |         \-MAWA
#                  |
#                  |   /-CAWA
#                   \-|
#                     |   /-BTBW
#                      \-|
#                        |   /-OVEN
#                         \-|
#                            \-BAWW
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  13.0
# Normalized Score: 0.8461538461538461
# Random Trees with Equivalent or More Congruent Score: 241
# Total Trees: 10000
# P-Value: 0.0241
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   42.0
# Max Stochastic Metric:  81.0
# Normalized Score: 0.5185185185185185
# Random Trees with Equivalent or More Congruent Score: 3
# Total Trees: 10000
# P-Value: 0.0003
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  12.0
# Normalized Score: 0.8333333333333334
# Random Trees with Equivalent or More Congruent Score: 380
# Total Trees: 10000
# P-Value: 0.038
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   27.0
# Max Stochastic Metric:  57.0
# Normalized Score: 0.47368421052631576
# Random Trees with Equivalent or More Congruent Score: 22
# Total Trees: 10000
# P-Value: 0.0022

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/results_unifrac/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_unifrac_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
# --|   /-WEWA
#   |  |
#   |  |   /-BAWW
#    \-|  |
#      |  |      /-NAWA
#      |  |   /-|
#      |  |  |   \-COYE
#       \-|  |
#         |  |         /-HOWA
#         |  |      /-|
#         |  |     |   \-AMRE
#         |  |     |
#          \-|   /-|   /-BTBW
#            |  |  |  |
#            |  |  |  |         /-NOPA
#            |  |  |  |      /-|
#            |  |   \-|     |   \-MAWA
#            |  |     |   /-|
#            |  |     |  |  |   /-BLBW
#             \-|     |  |   \-|
#               |      \-|      \-CSWA
#               |        |
#               |        |   /-MYWA
#               |         \-|
#               |            \-BTNW
#               |
#                \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-NAWA
#   |
#   |         /-HOWA
#   |      /-|
#   |     |   \-WEWA
#   |   /-|
#   |  |  |   /-AMRE
# --|  |   \-|
#   |  |     |   /-CSWA
#   |  |      \-|
#   |  |        |   /-OVEN
#   |  |         \-|
#   |  |           |   /-NOPA
#   |  |            \-|
#   |  |              |   /-CAWA
#    \-|               \-|
#      |                 |   /-COYE
#      |                  \-|
#      |                    |   /-MAWA
#      |                     \-|
#      |                       |   /-MYWA
#      |                        \-|
#      |                           \-BLBW
#      |
#      |   /-BAWW
#       \-|
#         |   /-BTBW
#          \-|
#             \-BTNW
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   13.0
# Max Stochastic Metric:  13.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   55.0
# Max Stochastic Metric:  81.0
# Normalized Score: 0.6790123456790124
# Random Trees with Equivalent or More Congruent Score: 595
# Total Trees: 10000
# P-Value: 0.0595
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   12.0
# Max Stochastic Metric:  12.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   48.0
# Max Stochastic Metric:  58.0
# Normalized Score: 0.8275862068965517
# Random Trees with Equivalent or More Congruent Score: 9754
# Total Trees: 10000
# P-Value: 0.9754

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/results_weightedunifrac/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_weightedunifrac_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
# --|   /-WEWA
#   |  |
#   |  |   /-BAWW
#    \-|  |
#      |  |      /-NAWA
#      |  |   /-|
#      |  |  |   \-COYE
#       \-|  |
#         |  |         /-HOWA
#         |  |      /-|
#         |  |     |   \-AMRE
#         |  |     |
#          \-|   /-|   /-BTBW
#            |  |  |  |
#            |  |  |  |         /-NOPA
#            |  |  |  |      /-|
#            |  |   \-|     |   \-MAWA
#            |  |     |   /-|
#            |  |     |  |  |   /-BLBW
#             \-|     |  |   \-|
#               |      \-|      \-CSWA
#               |        |
#               |        |   /-MYWA
#               |         \-|
#               |            \-BTNW
#               |
#                \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-NAWA
#   |
# --|   /-COYE
#   |  |
#   |  |   /-CSWA
#    \-|  |
#      |  |   /-WEWA
#      |  |  |
#       \-|  |            /-BLBW
#         |  |         /-|
#         |  |        |  |   /-BTBW
#         |  |        |   \-|
#         |  |      /-|      \-BAWW
#          \-|     |  |
#            |     |  |   /-NOPA
#            |   /-|   \-|
#            |  |  |      \-BTNW
#            |  |  |
#            |  |  |   /-OVEN
#            |  |   \-|
#             \-|     |   /-AMRE
#               |      \-|
#               |         \-HOWA
#               |
#               |   /-MYWA
#                \-|
#                  |   /-MAWA
#                   \-|
#                      \-CAWA
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   12.0
# Max Stochastic Metric:  13.0
# Normalized Score: 0.9230769230769231
# Random Trees with Equivalent or More Congruent Score: 2286
# Total Trees: 10000
# P-Value: 0.2286
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   47.0
# Max Stochastic Metric:  81.0
# Normalized Score: 0.5802469135802469
# Random Trees with Equivalent or More Congruent Score: 42
# Total Trees: 10000
# P-Value: 0.0042
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  12.0
# Normalized Score: 0.8333333333333334
# Random Trees with Equivalent or More Congruent Score: 365
# Total Trees: 10000
# P-Value: 0.0365
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   35.0
# Max Stochastic Metric:  56.0
# Normalized Score: 0.625
# Random Trees with Equivalent or More Congruent Score: 1007
# Total Trees: 10000
# P-Value: 0.1007

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/results_jaccard/'

##################################################

### PATH TO THE HOST TREE ###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/TreeCmp/newick_warblers.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_merged/qiime_diversity/core-metrics-results_filtered/grouped_beta/newick_jaccard_grouped.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-OVEN
#   |
# --|   /-WEWA
#   |  |
#   |  |   /-BAWW
#    \-|  |
#      |  |      /-NAWA
#      |  |   /-|
#      |  |  |   \-COYE
#       \-|  |
#         |  |         /-HOWA
#         |  |      /-|
#         |  |     |   \-AMRE
#         |  |     |
#          \-|   /-|   /-BTBW
#            |  |  |  |
#            |  |  |  |         /-NOPA
#            |  |  |  |      /-|
#            |  |   \-|     |   \-MAWA
#            |  |     |   /-|
#            |  |     |  |  |   /-BLBW
#             \-|     |  |   \-|
#               |      \-|      \-CSWA
#               |        |
#               |        |   /-MYWA
#               |         \-|
#               |            \-BTNW
#               |
#                \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-NAWA
#   |
#   |      /-HOWA
#   |   /-|
#   |  |   \-WEWA
# --|  |
#   |  |      /-BTNW
#   |  |     |
#   |  |     |      /-CSWA
#   |  |     |   /-|
#   |  |     |  |  |   /-COYE
#    \-|   /-|  |   \-|
#      |  |  |  |     |   /-BLBW
#      |  |  |  |      \-|
#      |  |  |  |        |   /-NOPA
#      |  |  |  |         \-|
#      |  |   \-|           |   /-CAWA
#      |  |     |            \-|
#      |  |     |              |   /-MYWA
#       \-|     |               \-|
#         |     |                  \-MAWA
#         |     |
#         |     |   /-AMRE
#         |      \-|
#         |         \-OVEN
#         |
#         |   /-BTBW
#          \-|
#             \-BAWW
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   13.0
# Max Stochastic Metric:  13.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   47.0
# Max Stochastic Metric:  81.0
# Normalized Score: 0.5802469135802469
# Random Trees with Equivalent or More Congruent Score: 34
# Total Trees: 10000
# P-Value: 0.0034
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   12.0
# Max Stochastic Metric:  12.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   40.0
# Max Stochastic Metric:  59.0
# Normalized Score: 0.6779661016949152
# Random Trees with Equivalent or More Congruent Score: 4588
# Total Trees: 10000
# P-Value: 0.4588
