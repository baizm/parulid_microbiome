# %%
import os
import numpy as np
import pandas as pd
from ete3 import Tree
import random
import subprocess
random.seed(191919)  # Set Random Seed for Reproducibility

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/results_braycurtis/'

##################################################

### PATH TO THE HOST TREE (diet dendrogram)###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/newick_bray_grouped.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/sub_NY_forCO1/newick_bray_NY.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#       /-COYE
#    /-|
#   |   \-OVEN
#   |
# --|   /-BTBW
#   |  |
#   |  |      /-NOPA
#   |  |   /-|
#    \-|  |  |   /-BTNW
#      |  |   \-|
#      |  |     |   /-CAWA
#      |  |      \-|
#       \-|        |   /-NAWA
#         |         \-|
#         |            \-MYWA
#         |
#         |   /-BAWW
#          \-|
#            |   /-AMRE
#             \-|
#               |   /-CSWA
#                \-|
#                  |   /-BLBW
#                   \-|
#                      \-MAWA
#
#  --- MICROBIOME TREE ---
#
#       /-BTNW
#      |
#      |      /-NAWA
#      |     |
#      |     |      /-BTBW
#      |     |   /-|
#    /-|   /-|  |  |   /-BLBW
#   |  |  |  |  |   \-|
#   |  |  |  |  |     |   /-MYWA
#   |  |  |  |  |      \-|
#   |  |  |   \-|        |   /-NOPA
#   |  |  |     |         \-|
#   |   \-|     |            \-MAWA
#   |     |     |
# --|     |     |   /-CAWA
#   |     |      \-|
#   |     |         \-BAWW
#   |     |
#   |     |   /-CSWA
#   |      \-|
#   |         \-AMRE
#   |
#   |   /-COYE
#    \-|
#       \-OVEN
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   9.0
# Max Stochastic Metric:  11.0
# Normalized Score: 0.8181818181818182
# Random Trees with Equivalent or More Congruent Score: 180
# Total Trees: 10000
# P-Value: 0.018
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   33.0
# Max Stochastic Metric:  62.0
# Normalized Score: 0.532258064516129
# Random Trees with Equivalent or More Congruent Score: 408
# Total Trees: 10000
# P-Value: 0.0408
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   9.0
# Max Stochastic Metric:  10.0
# Normalized Score: 0.9
# Random Trees with Equivalent or More Congruent Score: 1710
# Total Trees: 10000
# P-Value: 0.171
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   32.0
# Max Stochastic Metric:  44.0
# Normalized Score: 0.7272727272727273
# Random Trees with Equivalent or More Congruent Score: 5864
# Total Trees: 10000
# P-Value: 0.5864

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/results_unifrac/'

##################################################

### PATH TO THE HOST TREE (diet dendrogram)###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/newick_unifrac_grouped.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/sub_NY_forCO1/newick_unifrac_NY.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-BAWW
#   |
# --|   /-AMRE
#   |  |
#    \-|      /-NAWA
#      |   /-|
#      |  |   \-MAWA
#       \-|
#         |   /-COYE
#          \-|
#            |   /-OVEN
#             \-|
#               |   /-BTBW
#                \-|
#                  |   /-BTNW
#                   \-|
#                     |   /-BLBW
#                      \-|
#                        |   /-CAWA
#                         \-|
#                           |   /-CSWA
#                            \-|
#                              |   /-NOPA
#                               \-|
#                                  \-MYWA
#
#  --- MICROBIOME TREE ---
#
#    /-BLBW
#   |
#   |      /-CSWA
# --|   /-|
#   |  |   \-BAWW
#   |  |
#    \-|      /-BTNW
#      |   /-|
#      |  |  |   /-NOPA
#      |  |   \-|
#       \-|      \-BTBW
#         |
#         |   /-AMRE
#          \-|
#            |   /-NAWA
#             \-|
#               |   /-OVEN
#                \-|
#                  |   /-COYE
#                   \-|
#                     |   /-CAWA
#                      \-|
#                        |   /-MYWA
#                         \-|
#                            \-MAWA
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  11.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   47.0
# Max Stochastic Metric:  68.0
# Normalized Score: 0.6911764705882353
# Random Trees with Equivalent or More Congruent Score: 1441
# Total Trees: 10000
# P-Value: 0.1441
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  10.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   36.0
# Max Stochastic Metric:  48.0
# Normalized Score: 0.75
# Random Trees with Equivalent or More Congruent Score: 7100
# Total Trees: 10000
# P-Value: 0.71

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/results_weightedunifrac/'

##################################################

### PATH TO THE HOST TREE (diet dendrogram)###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/newick_weightedunifrac_grouped.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/sub_NY_forCO1/newick_weightedunifrac_NY.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-NOPA
#   |
# --|   /-BTBW
#   |  |
#    \-|   /-AMRE
#      |  |
#       \-|   /-BTNW
#         |  |
#          \-|   /-NAWA
#            |  |
#             \-|   /-CSWA
#               |  |
#               |  |      /-OVEN
#                \-|   /-|
#                  |  |  |   /-CAWA
#                  |  |   \-|
#                   \-|      \-COYE
#                     |
#                     |   /-BAWW
#                      \-|
#                        |   /-MYWA
#                         \-|
#                           |   /-BLBW
#                            \-|
#                               \-MAWA
#
#  --- MICROBIOME TREE ---
#
#    /-COYE
#   |
# --|   /-OVEN
#   |  |
#    \-|   /-CSWA
#      |  |
#      |  |   /-AMRE
#       \-|  |
#         |  |      /-NAWA
#         |  |   /-|
#          \-|  |  |   /-CAWA
#            |  |   \-|
#            |  |     |   /-BTNW
#            |  |      \-|
#            |  |        |   /-MAWA
#             \-|         \-|
#               |           |   /-NOPA
#               |            \-|
#               |               \-MYWA
#               |
#               |   /-BLBW
#                \-|
#                  |   /-BTBW
#                   \-|
#                      \-BAWW
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  11.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   50.0
# Max Stochastic Metric:  68.0
# Normalized Score: 0.7352941176470589
# Random Trees with Equivalent or More Congruent Score: 3402
# Total Trees: 10000
# P-Value: 0.3402
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  10.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   34.0
# Max Stochastic Metric:  44.0
# Normalized Score: 0.7727272727272727
# Random Trees with Equivalent or More Congruent Score: 7713
# Total Trees: 10000
# P-Value: 0.7713

# %%
##### USER INPUT #################################

### INPUT/OUTPUT FOLDER ###
outPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/results_jaccard/'

##################################################

### PATH TO THE HOST TREE (diet dendrogram)###
htPath = '/Users/marcellabaiz/Documents/Toews_Lab/warbler_diet/grouped_diet/topology_analyses/subset_NY_2017to2019/newick_jaccard_grouped.newick'

### PATH TO MICROBIOME DENDROGRAM (OR ALTERNATIVE TREE) ###
mtPath = '/Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/silva/phyloseq/decontaminated/qiime_diversity/sub_NY_forCO1/newick_jaccard_NY.newick'

### NUMBER OF RANDOM TREES ###
numRandom = 10000

# %%
##### IMPORT AND CLEAN TREES #########################################################

### IMPORT HOST TREE ###
htIn = Tree(htPath)
### IMPORT MICROBIOME TREE ###
mtIn = Tree(mtPath)

### PRINT THE TREES ###
print('\n --- HOST TREE --- ')
print(htIn)
print('\n --- MICROBIOME TREE --- ')
print(mtIn)

### LIST TO STORE HOST LEAVES ###
htLeafs = []

### CHECK THAT TREES HAVE SAME NUMBER OF LEAVES ###
print('\n --- CHECKING TREES --- \n')
if len(htIn) == len(mtIn):   
    
    ### FOR EACH LEAF IN THE HOST TREE MAKE SURE ALSO IN MICROBIOME TREE ###
    for leaf in mtIn:
        
        ### STORE LEAF NAME ###
        htLeafs.append(leaf.name)
        
        ### CHECK MICROBIOME TREE ###
        if leaf.name not in mtIn:
            print('ERROR - '+leaf.name+' Not Found in Microbiome Tree!')

### # IF NOT SAME NUMBER OF LEAVES PRINT ERROR ###
else: print('ERROR - Host and Microbiome Tree Have Different Numbers of Nodes!')

##### GENERATING RANDOM TREES ########################################################

### PATH TO STORE RANDOM TREES ###
rtPath = outPath+'/random_trees/'

### CREATE OUTPUT FOLDER ###
if not os.path.isdir(rtPath): os.makedirs(rtPath)

### FOR EACH RANDOM TREE ###
for curRandom in np.arange(numRandom):
    
    ### INTITALIZE RANDOM TREE ###
    t = Tree()
    
    ### SHUFFLE LEAVES ###
    random.shuffle(htLeafs)
    
    ### POPULATE TREE ###
    t.populate(len(htIn), names_library=htLeafs)
    
    ### WRITE TREE ###
    t.write(outfile=rtPath+'/tree_'+str(curRandom)+'.newick')

### CONCATENATE THE RANDOM TREES INTO SINGLE FILE ###
subprocess.check_output(str('for i in '+outPath+'/random_trees/*; do  cat $i >> '+outPath+'/random_trees.newick; done'), shell=True)

##### COMARE WITH TREECMP METHODS ####################################################

### FOR EACH TREECMP METHOD ###
methods = {"rc":'Rooted Robinson-Foulds', "mc":'Rooted Matching Cluster', "ms":'Unrooted Matching Split', "rf":'Unrooted Robinson-Foulds'}

for method in ["rc", "mc", "rf", "ms"]:
    
    ### MAKE COMPARISON FOLDER ###
    if not os.path.isdir(outPath+'/compare_'+method+'/'): os.makedirs(outPath+'/compare_'+method+'/')
        
    ### COMPARE HOST AND MICROBIOME TREE ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+mtPath+' -o '+outPath+'/compare_'+method+'/compare_ht_mt.txt -N'), shell=True)
    
    ### COMPARE HOST AND RANDOM TREES ###
    subprocess.check_output(str('java -jar /Users/marcellabaiz/Documents/Toews_Lab/16s_data/Jan2020/TreeCmp/TreeCmp_v2.0-b76/bin/treeCmp.jar -r '+htPath+
              ' -d '+method+' -i '+outPath+'/random_trees.newick -o '+outPath+'/compare_'+method+'/compare_ht_random.txt -N'), shell=True)

    ### READ IN COMPARISON RESULTS ###
    mtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_mt.txt', sep='\t')
    rtCompare = pd.read_csv(outPath+'/compare_'+method+'/compare_ht_random.txt', sep='\t')

    ### PRINT RESULTS ###
    print(' --- METHOD: '+methods[method]+' --- ')
    print("Host-Microbe Score:   " + str(mtCompare.iloc[0,3]))
    print("Max Stochastic Metric:  " + str(max(rtCompare.iloc[:,3])))
    print('Normalized Score: '+str(mtCompare.iloc[0,3]/max(rtCompare.iloc[:,3])))
    print('Random Trees with Equivalent or More Congruent Score: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]])))
    print('Total Trees: '+ str(len(rtCompare)))
    print('P-Value: '+str(len(rtCompare[rtCompare.iloc[:,3] <= mtCompare.iloc[0,3]]) / len(rtCompare))+'\n')
# Out:
#  --- HOST TREE ---
#
#    /-AMRE
#   |
# --|   /-COYE
#   |  |
#    \-|   /-OVEN
#      |  |
#       \-|   /-BAWW
#         |  |
#          \-|   /-CSWA
#            |  |
#             \-|   /-BTBW
#               |  |
#               |  |      /-BLBW
#                \-|   /-|
#                  |  |  |   /-NOPA
#                  |  |   \-|
#                  |  |     |   /-BTNW
#                   \-|      \-|
#                     |         \-MYWA
#                     |
#                     |   /-MAWA
#                      \-|
#                        |   /-NAWA
#                         \-|
#                            \-CAWA
#
#  --- MICROBIOME TREE ---
#
#    /-BAWW
# --|
#   |   /-OVEN
#    \-|
#      |   /-AMRE
#       \-|
#         |   /-CSWA
#          \-|
#            |   /-BTNW
#             \-|
#               |   /-COYE
#                \-|
#                  |   /-NAWA
#                   \-|
#                     |   /-BTBW
#                      \-|
#                        |   /-NOPA
#                         \-|
#                           |   /-BLBW
#                            \-|
#                              |   /-MAWA
#                               \-|
#                                 |   /-MYWA
#                                  \-|
#                                     \-CAWA
#
#  --- CHECKING TREES ---
#
#  --- METHOD: Rooted Robinson-Foulds ---
# Host-Microbe Score:   11.0
# Max Stochastic Metric:  11.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Rooted Matching Cluster ---
# Host-Microbe Score:   30.0
# Max Stochastic Metric:  68.0
# Normalized Score: 0.4411764705882353
# Random Trees with Equivalent or More Congruent Score: 2
# Total Trees: 10000
# P-Value: 0.0002
#
#  --- METHOD: Unrooted Robinson-Foulds ---
# Host-Microbe Score:   10.0
# Max Stochastic Metric:  10.0
# Normalized Score: 1.0
# Random Trees with Equivalent or More Congruent Score: 10000
# Total Trees: 10000
# P-Value: 1.0
#
#  --- METHOD: Unrooted Matching Split ---
# Host-Microbe Score:   28.0
# Max Stochastic Metric:  44.0
# Normalized Score: 0.6363636363636364
# Random Trees with Equivalent or More Congruent Score: 1637
# Total Trees: 10000
# P-Value: 0.1637
